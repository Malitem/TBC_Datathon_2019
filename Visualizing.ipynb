# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import pyplot
import seaborn as sns

# %matplotlib inline
# %run ../Veon_Tasks/functions_book.ipynb

# %%
df = pd.read_csv("final.csv")

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df = df.set_index(['პოლისის ნომერი (hash)', 'დამზღ პირადი ნომერი (hash)'])

# %%
df.drop(['სედანი/ჯიპი', 'სტატუსი'],axis=1, inplace=True)

# %%
df.drop(['გაუქმებული პრემია', 'გასული_პერიოდი_გაუქმებამდე'],axis=1, inplace=True)

# %%
display_all(df.head())
# Out:
#                                                                                                        წინა პოლისის ნომერი (hash)  \
# პოლისის ნომერი (hash)                              დამზღ პირადი ნომერი (hash)
# a33fff3fbe65ff7923448554f5f32f05b52ddf1f4cf88d0... 5c05f5ab96ae3736b288a7121c222b86a82c221e782b4dd...                           0
# 1caa70ee07ef8cb0f55f06f6bf43cb7d4853b13fe837a4e... 70720759877097d63afb1e59d5f535413076b92a48e616f...                           0
# 634cc57a6f4ba919e81c0f01b7530de1f660b67183f597a... 21af9ba2c667dc7758c1d8fee8cf845c10a2b912077ff32...                           0
# 6e58638e7cd1bb63394922816cdbc8a1e50cc6ae6206cb9... ce3f168dac3aa97e04b770006e29b2bc6a5a4dca34a1981...                           0
# e831f0776cd9fd656387eb9de5a72009f1f747ce8d90e3f... be7f92e24d1ad7c35f4b44afde3077178512c4a846da5f4...                           0
#
# ...

# %%
df1 = df[df['ბოლომდე არ გადაიხადა'] == 1] # bolomde ar gadaixada

# %%
df2 = df[df['ბოლომდე არ გადაიხადა'] == 0] # bolomde gadaixada

# %%
features_to_check = [
 'პრემია',
 'დამზღვევის ასაკი',
 'პასუხისმგებლის ასაკი',
 'in_answered',
 'ვადაგადაცილებული დღე',
 'გარეცხვის რაოდენობა',
 'მოთხოვნილი',
 'თანამშრომლი ქალია',
 'დამზღ არის მესაკუთრე'
]

# %%
Box_and_Hist_Plots(result1,'in_answered',bins=15)
# Out:
# C:\Users\TMalishava\AppData\Local\Continuum\anaconda3\envs\testenv\lib\site-packages\ipykernel_launcher.py:30: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# (        bins  frequency
#  0   1.000000        827
#  1   1.266667          0
#  2   1.533333          0
#  3   1.800000        485
#  4   2.066667          0
#  5   2.333333          0
#  6   2.600000          0
#  7   2.866667        256
#  8   3.133333          0
#  9   3.400000          0
#  10  3.666667          0
#  11  3.933333        170
#  12  4.200000          0
#  13  4.466667          0
#  14  4.733333        112
#  15  5.000000       -999, None)

# %%
Box_and_Hist_Plots(result1,'გარეცხვის რაოდენობა',bins=15)
# Out:
# C:\Users\TMalishava\AppData\Local\Continuum\anaconda3\envs\testenv\lib\site-packages\ipykernel_launcher.py:30: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# (         bins  frequency
#  0    1.000000        285
#  1    1.733333        159
#  2    2.466667        128
#  3    3.200000          0
#  4    3.933333         87
#  5    4.666667         53
#  6    5.400000         32
#  7    6.133333          0
#  8    6.866667         31
#  9    7.600000         29
#  10   8.333333         25
#  11   9.066667          0
#  12   9.800000         13
#  13  10.533333         22
#  14  11.266667          9
#  15  12.000000       -999, None)

# %%
plt.figure(num=None, figsize=(10, 5), dpi=80, facecolor='w', edgecolor='k')

plt.title('არის თუ არა დამზღვევი პირი მესაკუთრე?', size = 17)
plt.pie(df['დამზღ არის მესაკუთრე'].value_counts(), labels = ['არის', 'არ არის'], autopct='%1.1f%%', colors = ["grey","yellow"], 
        shadow=True, startangle=270);
